# %% [markdown]
# <a href="https://colab.research.google.com/github/manoharpavuluri/Playing_Huggingface_With_Langchain/blob/main/Huggingface_With_Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries required
# !pip install langchain-huggingface
# for api calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain

# %%
# environment secret keys
from google.colab import userdata
sec_key=userdata.get("HUGGINGFACEHUB_API_TOKEN")
print(sec_key)
# Out:
# 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

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,
                        max_length=128,
                        temperature=0.7,
                        token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("Who is 'Deepthi Bollu'?")
# Out:
# " She is a social media influencer who has gained popularity through her YouTube channel. Deepthi Bollu is a YouTuber, TikToker, and content creator who is known for her beauty, fashion, and lifestyle videos. She has amassed a significant following on various social media platforms, including YouTube, TikTok, and Instagram, where she shares her creative content with her fans.\n\nDeepthi Bollu was born on October 11, 1997, in Hyderabad, India. She grew up in a middle-class family and completed her education in Hyderabad. After finishing her studies, she moved to the United States to pursue her career in content creation. She started her YouTube channel in 2014, and since then, she has been creating and sharing videos related to beauty, fashion, and lifestyle.\n\nDeepthi Bollu's YouTube channel has over 3 million subscribers, and she has accumulated over 100 million views on her videos. She is known for her engaging and entertaining content, which includes makeup tutorials, fashion hau
# ...

# %%
from langchain import PromptTemplate, LLMChain

question = "who can be the president of United States in 2025?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template = template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm=LLMChain(llm=llm,prompt=prompt)

# %%
print(llm.run(question))
# Out:
#  The President of the United States is elected every four years. The term of the current President, Joe Biden, will end in 2025. Therefore, to be the President in 2025, one would have to be elected in the Presidential Election of 2024.
#
# The eligibility criteria for the President of the United States, as stated in the U.S. Constitution, are:
# 1. The person must be a natural-born citizen of the United States.
# 2. The person must be at least 35 years old.
# 3. The person must have been a resident of the United States for at least 14 years.
#
# ...

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# %%
model_id="gpt2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenize=AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
pipe=pipeline("text-generation", model=model, tokenizer=tokenize, max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)
hf
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7d802fa2c730>)

# %%
hf.invoke("who is Ishaan Pavuluri")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'who is Ishaan Pavuluri, a well-funded independent watchdog group that has also been on loan by the Russian state-owned oil company Rosneft for its efforts to influence a 2016 European Union energy negotiations.\n\nThe group claims it was responsible for funding the Russian efforts to influence the EU\'s energy policies and was "responsible for setting the agenda". Russia\'s energy minister, Andrei Novik, said in a state of panic.\n\n"It is clear that the EU and Rosneft have no responsibility for'

# %%
# use Huggingface with GPU
gpu_llm= HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=0,
    pipeline_kwargs={"max_new_tokens":100},
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain_core.prompts import PromptTemplate


template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
chain=prompt|gpu_llm
question = "what is Artificial intelligence?"
chain.invoke({"question":question})
# Out:
# "Question: what is Artificial intelligence?\nAnswer: Let's think step by step. We're starting with a question. What is the real difference between AI and machine learning? This is where we're focusing more attention. It's important to acknowledge that machine learning is a good idea in the sense that it reduces all sorts of cognitive and logical biases that come with machine learning. This involves reducing some of the biases that machine learning can cause such as biases about intelligence and memory.\nThere is a fundamental problem with artificial intelligence. Machines have cognitive biases against other humans. That's a problem"
